# %% [markdown]
# ## Name : Vaidehi Deshmukh
# ## College : P.E.S Modern College of Engineering
# ## Task 2 : UNEMPLOYMENT ANALYSIS WITH PYTHON

# %% [markdown]
# # To analyze the Unemployment rate

# %% [markdown]
# ## Importing Libraries and Loading The Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data= pd.read_csv('Unemployment in India.csv.xls')
data= pd.read_csv('Unemployment_Rate_upto_11_2020.csv.xls')

# %%
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %% [markdown]
# ## Domain Analysis

# %% [markdown]
# - Region = states in India
# - Date = date which the unemployment rate observed
# - Frequency = measuring frequency (Monthly)
# - Estimated Unemployment Rate (%) = percentage of people unemployed in each States of India
# - Estimated Employed = percentage of people employed
# - Estimated Labour Participation Rate (%) = labour force participation rate by dividing the number of people actively participating in the labour force by the
# total number of people eligible to participate in the labor force
# force
# - Area = Employment and unemployment rates in Urban and rural areas

# %% [markdown]
# ## Basic Checks

# %%
data.shape
# Out:
# (267, 9)

# %%
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
data.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %% [markdown]
# #### Insigths

# %% [markdown]
# - There are 768 rows and 7 columns
# - NaN values are present
# - Object and Float data type is present
# - The minimum Estimated Unemployment Rate is 0% and maximum is 76.7%
# - The minimum Estimated Labour Participation Rate is 13.3% and maximum is 72.5%

# %% [markdown]
# ## Data Cleaning

# %%
# Step 1 : Check missing values
data.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
data.columns = ['States','Date','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate ','Region','Longitude','Latitude']

# %%
# Step 2 : Check Duplicated Data
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html()
# Out:
# /Users/vaidehideshmukh/jupyter/lib/python3.10/site-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /Users/vaidehideshmukh/jupyter/lib/python3.10/site-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
#                                              |      | [  0%]   00:00 -> (? left)
# /Users/vaidehideshmukh/jupyter/lib/python3.10/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# ...

# %%
sns.pairplot(data=data)

# %%
sns.histplot(hue='Region',x='Estimated Unemployment Rate',data=data)
plt.show()

# %%
sns.histplot(hue='Region',x='Estimated Employed',data=data)
plt.show()

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()
# Out:
# /var/folders/2x/bvptsh3d6974nz8w90r0jggw0000gn/T/ipykernel_12611/2246898758.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)

# %%
plt.figure(figsize=(20,25))
sns.barplot(y='Estimated Unemployment Rate',x='States',data=data)
plt.show()

# %%
plt.figure(figsize=(20,25))
sns.barplot(y='Estimated Employed',x='States',data=data)
plt.show()
